# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Homework Questions
#
# 1. *Load Data*: Load the given CSV file into a Pandas DataFrame and verify that the data has been loaded by displaying the first five rows.

# %%
df = pd.read_csv('/content/drive/MyDrive/Anudip/employee_data_with_nulls_duplicates.csv')
df.head()
# Out:
#   EmployeeID FirstName  LastName   Age Department  Salary          City  \
# 0      E0001     David    Miller  26.0         IT   75734      New York
# 1      E0002     Sarah  Williams  49.0         IT   95339       Chicago
# 2      E0003     Katie   Johnson  53.0      Sales   80644  Philadelphia
# 3      E0004     Sarah   Johnson  40.0      Sales   57543   Los Angeles
# 4      E0005     Emily     Brown   NaN    Finance   47484       Chicago
#
#   JoiningDate
# 0  2010-12-27
# 1  2014-01-21
# 2  2018-09-14
# 3  2017-09-24
# 4  2013-11-14

# %% [markdown]
# 2. *View Structure*: Display the structure of the DataFrame, including the total number of rows and columns, and the column names.
#
# 3. *Check Data Types*: Check and print the data types of each column in the DataFrame.

# %%
df.shape
# Out:
# (105, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   105 non-null    object
#  1   FirstName    105 non-null    object
#  2   LastName     105 non-null    object
#  3   Age          95 non-null     float64
#  4   Department   105 non-null    object
#  5   Salary       105 non-null    int64
#  6   City         105 non-null    object
#  7   JoiningDate  105 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.7+ KB

# %% [markdown]
# 4. *Missing Values*: Identify if there are any missing (null) values in the "Age" column of the DataFrame.

# %%
df.isnull().sum()
# Out:
# EmployeeID      0
# FirstName       0
# LastName        0
# Age            10
# Department      0
# Salary          0
# City            0
# JoiningDate     0
# dtype: int64

# %% [markdown]
# 5. *Fill Missing Values*: Replace the missing values in the "Age" column with the mean value of the "Age" column.

# %%
df['Age'].fillna(value=df['Age'].mean(), inplace = True)
# Out:
# <ipython-input-7-ac800a06b6bd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(value=df['Age'].mean(), inplace = True)

# %% [markdown]
# 6. *Duplicate Records*: Check for duplicate rows in the DataFrame and count how many duplicate rows exist.
#
# 7. *Remove Duplicates*: Remove the duplicate rows from the DataFrame and verify that duplicates have been removed by checking the new shape of the DataFrame.

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df = df.drop_duplicates()
df
# Out:
#    EmployeeID FirstName  LastName        Age   Department  Salary  \
# 0       E0001     David    Miller  26.000000           IT   75734
# 1       E0002     Sarah  Williams  49.000000           IT   95339
# 2       E0003     Katie   Johnson  53.000000        Sales   80644
# 3       E0004     Sarah   Johnson  40.000000        Sales   57543
# 4       E0005     Emily     Brown  40.789474      Finance   47484
# ..        ...       ...       ...        ...          ...     ...
# 95      E0096     Sarah     Jones  53.000000           IT  111354
# 96      E0097     David    Miller  29.000000           IT   41395
# 97      E0098     Emily  Williams  40.789474           IT   60334
# 98      E0099     Laura    Miller  41.000000    Marketing   95117
# 99      E0100   Michael     Brown  33.000000  Engineering   87932
#
#             City JoiningDate
# 0       New York  2010-12-27
# 1        Chicago  2014-01-21
# 2   Philadelphia  2018-09-14
# 3    Los Angeles  2017-09-24
# ...

# %% [markdown]
# 8. *Filter by Condition*: Select and display all employees who belong to the "Marketing" department and have a salary greater than 80,000.

# %%
df[(df['Department']=='Marketing') & (df['Salary']>80000)]
# Out:
#    EmployeeID FirstName   LastName   Age Department  Salary          City  \
# 7       E0008     Laura     Garcia  36.0  Marketing   92137      New York
# 33      E0034      John     Garcia  58.0  Marketing  107107  Philadelphia
# 37      E0038     Sarah    Johnson  23.0  Marketing  105078   Los Angeles
# 51      E0052   Michael    Johnson  51.0  Marketing   92887  Philadelphia
# 62      E0063     Emily  Rodriguez  53.0  Marketing  106610      New York
# 67      E0068     Laura     Garcia  32.0  Marketing  103944   Los Angeles
# 73      E0074     Emily      Brown  42.0  Marketing  107596  Philadelphia
# 89      E0090     Emily   Williams  25.0  Marketing   81119       Chicago
# 98      E0099     Laura     Miller  41.0  Marketing   95117       Houston
#
#    JoiningDate
# 7   2015-06-24
# 33  2014-06-25
# 37  2022-02-01
# 51  2018-07-12
# 62  2015-03-17
# 67  2016-03-28
# 73  2012-08-06
# 89  2020-01-06
# 98  2022-05-04

# %% [markdown]
# 9. *Group by Department*: Group the data by the "Department" column and calculate the average salary for each department.

# %%
df.groupby('Department')[['Salary']].mean().round(2)
# Out:
#                Salary
# Department
# Engineering  72913.80
# Finance      72830.64
# HR           81359.30
# IT           85481.12
# Marketing    85425.36
# Sales        75552.33

# %% [markdown]
# 10. *New Column Addition*: Add a new column called "FullName" by concatenating the "FirstName" and "LastName" columns, separated by a space.

# %%
df['FullName'] = df['FirstName']+' '+df['LastName']
df['FullName']
# Out:
# 0       David Miller
# 1     Sarah Williams
# 2      Katie Johnson
# 3      Sarah Johnson
# 4        Emily Brown
#            ...
# 95       Sarah Jones
# 96      David Miller
# 97    Emily Williams
# 98      Laura Miller
# 99     Michael Brown
# Name: FullName, Length: 100, dtype: object

# %% [markdown]
# 11. *Age Statistics*: Find and display the minimum, maximum, and average age of the employees.

# %%
print('Minimum Age',df['Age'].min(),'\nMaximum Age',df['Age'].max(),'\nAverage Age',df['Age'].mean())
# Out:
# Minimum Age 23.0
# Maximum Age 60.0
# Average Age 40.51894736842105

# %%
df['Age'].describe()
# Out:
# count    100.000000
# mean      40.518947
# std       10.349109
# min       23.000000
# 25%       33.000000
# 50%       40.394737
# 75%       48.250000
# max       60.000000
# Name: Age, dtype: float64

# %% [markdown]
# 12. *Column Transformation*: Create a new column called "SalaryAfterTax" by subtracting 20% of the "Salary" (as tax) from the original "Salary" column.

# %%
df['SalaryAfterTax'] = df['Salary']-df['Salary']*0.2
df['SalaryAfterTax']
# Out:
# 0     60587.2
# 1     76271.2
# 2     64515.2
# 3     46034.4
# 4     37987.2
#        ...
# 95    89083.2
# 96    33116.0
# 97    48267.2
# 98    76093.6
# 99    70345.6
# Name: SalaryAfterTax, Length: 100, dtype: float64

# %% [markdown]
# 13. *Top Earners*: Find the top 5 highest-paid employees and display their details.

# %%
df.nlargest(5, ['Salary'])
# Out:
#    EmployeeID FirstName   LastName   Age Department  Salary         City  \
# 25      E0026   Michael     Miller  39.0         HR  119929      Houston
# 79      E0080      John  Rodriguez  57.0         IT  119815      Houston
# 32      E0033     Katie     Miller  27.0         IT  118042     New York
# 41      E0042     Emily     Garcia  48.0    Finance  117348      Houston
# 29      E0030     Katie  Rodriguez  54.0         HR  115717  Los Angeles
#
#    JoiningDate         FullName  SalaryAfterTax
# 25  2011-01-13   Michael Miller         95943.2
# 79  2014-01-18   John Rodriguez         95852.0
# 32  2013-06-11     Katie Miller         94433.6
# 41  2012-08-04     Emily Garcia         93878.4
# 29  2016-08-15  Katie Rodriguez         92573.6

# %%
df_top5 = df.sort_values(['Salary'], ascending=False).head(5)
df_top5
# Out:
#    EmployeeID FirstName   LastName   Age Department  Salary         City  \
# 25      E0026   Michael     Miller  39.0         HR  119929      Houston
# 79      E0080      John  Rodriguez  57.0         IT  119815      Houston
# 32      E0033     Katie     Miller  27.0         IT  118042     New York
# 41      E0042     Emily     Garcia  48.0    Finance  117348      Houston
# 29      E0030     Katie  Rodriguez  54.0         HR  115717  Los Angeles
#
#    JoiningDate         FullName  SalaryAfterTax
# 25  2011-01-13   Michael Miller         95943.2
# 79  2014-01-18   John Rodriguez         95852.0
# 32  2013-06-11     Katie Miller         94433.6
# 41  2012-08-04     Emily Garcia         93878.4
# 29  2016-08-15  Katie Rodriguez         92573.6

# %% [markdown]
# 14. *Data Sorting*: Sort the DataFrame based on the "JoiningDate" column in ascending order.

# %%
df["JoiningDate"] = pd.to_datetime(df["JoiningDate"])

# %%
df.sort_values(['JoiningDate'])
# Out:
#    EmployeeID FirstName  LastName        Age   Department  Salary  \
# 15      E0016     Katie     Brown  48.000000        Sales   77695
# 43      E0044     Chris     Davis  39.000000    Marketing   61719
# 54      E0055     Emily     Brown  43.000000  Engineering   65031
# 14      E0015     Emily     Brown  40.789474      Finance   90289
# 0       E0001     David    Miller  26.000000           IT   75734
# ..        ...       ...       ...        ...          ...     ...
# 48      E0049      Alex     Smith  38.000000  Engineering   52922
# 56      E0057      Alex  Martinez  42.000000  Engineering   74775
# 44      E0045     Emily     Smith  46.000000  Engineering   52826
# 70      E0071     Chris  Williams  38.000000           IT   67038
# 47      E0048     Emily  Williams  35.000000           HR   68221
#
#             City JoiningDate        FullName  SalaryAfterTax
# 15       Phoenix  2010-03-03     Katie Brown         62156.0
# ...

# %% [markdown]
# 15. *Subset of Columns*: Extract and display only the "EmployeeID", "FullName", "Department", and "City" columns as a new DataFrame.

# %%
new_df = df[['EmployeeID','FullName','Department','City']]
new_df
# Out:
#    EmployeeID        FullName   Department          City
# 0       E0001    David Miller           IT      New York
# 1       E0002  Sarah Williams           IT       Chicago
# 2       E0003   Katie Johnson        Sales  Philadelphia
# 3       E0004   Sarah Johnson        Sales   Los Angeles
# 4       E0005     Emily Brown      Finance       Chicago
# ..        ...             ...          ...           ...
# 95      E0096     Sarah Jones           IT       Houston
# 96      E0097    David Miller           IT       Chicago
# 97      E0098  Emily Williams           IT       Chicago
# 98      E0099    Laura Miller    Marketing       Houston
# 99      E0100   Michael Brown  Engineering       Chicago
#
# [100 rows x 4 columns]

# %% [markdown]
# 16. *Conditional Count*: Count the number of employees in the "IT" department who earn more than 60,000.

# %%
((df['Department']=='IT') & (df['Salary']>60000)).sum()
# Out:
# 14

# %% [markdown]
# 17. *Rename Columns*: Rename the column "City" to "Location" and display the updated DataFrame.

# %%
df.rename(columns={'City':'Location'},inplace=True)

# %%
df
# Out:
#    EmployeeID FirstName  LastName        Age   Department  Salary  \
# 0       E0001     David    Miller  26.000000           IT   75734
# 1       E0002     Sarah  Williams  49.000000           IT   95339
# 2       E0003     Katie   Johnson  53.000000        Sales   80644
# 3       E0004     Sarah   Johnson  40.000000        Sales   57543
# 4       E0005     Emily     Brown  40.789474      Finance   47484
# ..        ...       ...       ...        ...          ...     ...
# 95      E0096     Sarah     Jones  53.000000           IT  111354
# 96      E0097     David    Miller  29.000000           IT   41395
# 97      E0098     Emily  Williams  40.789474           IT   60334
# 98      E0099     Laura    Miller  41.000000    Marketing   95117
# 99      E0100   Michael     Brown  33.000000  Engineering   87932
#
#         Location JoiningDate        FullName  SalaryAfterTax
# 0       New York  2010-12-27    David Miller         60587.2
# ...

# %% [markdown]
# 18. *Filter by Joining Year*: Extract all employees who joined the company after the year 2018.

# %%
df4=df[df['JoiningDate']>='2019']

# %%
df4
# Out:
#    EmployeeID FirstName   LastName        Age   Department  Salary  \
# 8       E0009     Katie     Miller  28.000000           HR  107535
# 10      E0011     Emily      Jones  33.000000        Sales   70850
# 11      E0012   Michael  Rodriguez  37.000000  Engineering   73429
# 19      E0020     David      Brown  29.000000  Engineering   81682
# 23      E0024     Chris      Brown  35.000000           IT   67604
# 26      E0027   Michael      Smith  36.000000           HR   83570
# 27      E0028     Chris     Miller  48.000000        Sales   61023
# 28      E0029      Jane      Smith  47.000000  Engineering   77150
# 31      E0032   Michael    Johnson  26.000000        Sales   75543
# 37      E0038     Sarah    Johnson  23.000000    Marketing  105078
# 39      E0040     Laura      Jones  25.000000           HR   74954
# 42      E0043     Emily      Jones  32.000000           HR   54352
# 44      E0045     Emily      Smith  46.000000  Engineering   52826
# ...

# %% [markdown]
# 19. *Unique Values*: List all the unique cities (locations) present in the "City" column.

# %%
city_list = df['Location'].unique()
print(city_list)
# Out:
# ['New York' 'Chicago' 'Philadelphia' 'Los Angeles' 'Phoenix' 'Houston']

# %% [markdown]
# 20. *Average Salary by City*: Calculate and display the average salary of employees for each unique city.

# %%
df.groupby('Location')[['Salary']].mean().round(3)
# Out:
#                  Salary
# Location
# Chicago       71366.400
# Houston       87068.294
# Los Angeles   79338.158
# New York      76783.231
# Philadelphia  79698.400
# Phoenix       80137.625

# %% [markdown]
# 21. *Filter by Age Range*: Select all employees whose ages are between 30 and 45, inclusive.

# %%
df_age = df[(df['Age']<45) & (df['Age']>30)]
df_age
# Out:
#    EmployeeID FirstName   LastName        Age   Department  Salary  \
# 3       E0004     Sarah    Johnson  40.000000        Sales   57543
# 4       E0005     Emily      Brown  40.789474      Finance   47484
# 6       E0007   Michael   Martinez  34.000000      Finance   63069
# 7       E0008     Laura     Garcia  36.000000    Marketing   92137
# 10      E0011     Emily      Jones  33.000000        Sales   70850
# 11      E0012   Michael  Rodriguez  37.000000  Engineering   73429
# 12      E0013     David  Rodriguez  37.000000           HR   60482
# 13      E0014     Emily      Jones  31.000000  Engineering   81206
# 14      E0015     Emily      Brown  40.789474      Finance   90289
# 18      E0019     Chris      Jones  35.000000        Sales  104963
# 20      E0021     Chris   Martinez  35.000000      Finance   56516
# 21      E0022     Chris   Williams  43.000000  Engineering   55030
# 23      E0024     Chris      Brown  35.000000           IT   67604
# ...

# %% [markdown]
# 22. *Reset Index*: After filtering, reset the index of the DataFrame and drop the old index.

# %%
df_index = df_age.reset_index(drop=True)
df_index
# Out:
#    EmployeeID FirstName   LastName        Age   Department  Salary  \
# 0       E0004     Sarah    Johnson  40.000000        Sales   57543
# 1       E0005     Emily      Brown  40.789474      Finance   47484
# 2       E0007   Michael   Martinez  34.000000      Finance   63069
# 3       E0008     Laura     Garcia  36.000000    Marketing   92137
# 4       E0011     Emily      Jones  33.000000        Sales   70850
# 5       E0012   Michael  Rodriguez  37.000000  Engineering   73429
# 6       E0013     David  Rodriguez  37.000000           HR   60482
# 7       E0014     Emily      Jones  31.000000  Engineering   81206
# 8       E0015     Emily      Brown  40.789474      Finance   90289
# 9       E0019     Chris      Jones  35.000000        Sales  104963
# 10      E0021     Chris   Martinez  35.000000      Finance   56516
# 11      E0022     Chris   Williams  43.000000  Engineering   55030
# 12      E0024     Chris      Brown  35.000000           IT   67604
# ...

# %% [markdown]
# 23. *Add Derived Column*: Add a new column called "PerformanceScore" by generating random values between 1 and 10 for all employees.

# %%
df['PerformanceScore'] = np.random.randint(1,10,len(df))
df.head()
# Out:
#   EmployeeID FirstName  LastName        Age Department  Salary      Location  \
# 0      E0001     David    Miller  26.000000         IT   75734      New York
# 1      E0002     Sarah  Williams  49.000000         IT   95339       Chicago
# 2      E0003     Katie   Johnson  53.000000      Sales   80644  Philadelphia
# 3      E0004     Sarah   Johnson  40.000000      Sales   57543   Los Angeles
# 4      E0005     Emily     Brown  40.789474    Finance   47484       Chicago
#
#   JoiningDate        FullName  SalaryAfterTax  PerformanceScore
# 0  2010-12-27    David Miller         60587.2                 6
# 1  2014-01-21  Sarah Williams         76271.2                 5
# 2  2018-09-14   Katie Johnson         64515.2                 1
# 3  2017-09-24   Sarah Johnson         46034.4                 7
# 4  2013-11-14     Emily Brown         37987.2                 5

# %% [markdown]
# 24. *Age Distribution*: Create bins for the "Age" column (e.g., 20-30, 31-40, 41-50, 51+) and count the number of employees in each age group.

# %%
df['Age Group'] = pd.cut(df.Age,bins=[20,30,40,50,float('inf')],labels=['20-30','31-40','41-50','51+'])
df.head()
# Out:
#   EmployeeID FirstName  LastName        Age Department  Salary      Location  \
# 0      E0001     David    Miller  26.000000         IT   75734      New York
# 1      E0002     Sarah  Williams  49.000000         IT   95339       Chicago
# 2      E0003     Katie   Johnson  53.000000      Sales   80644  Philadelphia
# 3      E0004     Sarah   Johnson  40.000000      Sales   57543   Los Angeles
# 4      E0005     Emily     Brown  40.789474    Finance   47484       Chicago
#
#   JoiningDate        FullName  SalaryAfterTax  PerformanceScore Age Group
# 0  2010-12-27    David Miller         60587.2                 6     20-30
# 1  2014-01-21  Sarah Williams         76271.2                 5     41-50
# 2  2018-09-14   Katie Johnson         64515.2                 1       51+
# 3  2017-09-24   Sarah Johnson         46034.4                 7     31-40
# 4  2013-11-14     Emily Brown         37987.2                 5     41-50

# %% [markdown]
# 25. *Conditional Update*: Update the salaries of employees in the "Finance" department by increasing them by 15%, and display the updated rows.

# %%
df_new = df.copy()
df_new
# Out:
#    EmployeeID FirstName  LastName        Age   Department  Salary  \
# 0       E0001     David    Miller  26.000000           IT   75734
# 1       E0002     Sarah  Williams  49.000000           IT   95339
# 2       E0003     Katie   Johnson  53.000000        Sales   80644
# 3       E0004     Sarah   Johnson  40.000000        Sales   57543
# 4       E0005     Emily     Brown  40.789474      Finance   47484
# ..        ...       ...       ...        ...          ...     ...
# 95      E0096     Sarah     Jones  53.000000           IT  111354
# 96      E0097     David    Miller  29.000000           IT   41395
# 97      E0098     Emily  Williams  40.789474           IT   60334
# 98      E0099     Laura    Miller  41.000000    Marketing   95117
# 99      E0100   Michael     Brown  33.000000  Engineering   87932
#
#         Location JoiningDate        FullName  SalaryAfterTax  \
# 0       New York  2010-12-27    David Miller         60587.2
# ...

# %%
df_new.loc[df_new['Department'] == 'Finance', 'Salary'] = df_new['Salary']*1.15
df_new
# Out:
# <ipython-input-35-d575f625fe63>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 54606.6   72529.35 104629.3  103832.35  64993.4  134950.2   50114.7
#  129736.1   87045.8   55343.75 124085.    82329.65  56650.15  51727.  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_new.loc[df_new['Department'] == 'Finance', 'Salary'] = df_new['Salary']*1.15
#    EmployeeID FirstName  LastName        Age   Department    Salary  \
# 0       E0001     David    Miller  26.000000           IT   75734.0
# 1       E0002     Sarah  Williams  49.000000           IT   95339.0
# 2       E0003     Katie   Johnson  53.000000        Sales   80644.0
# 3       E0004     Sarah   Johnson  40.000000        Sales   57543.0
# 4       E0005     Emily     Brown  40.789474      Finance   54606.6
# ..        ...       ...       ...        ...          ...       ...
# ...

# %%
df_new['Salary']=df_new.apply(lambda row: row['Salary']*1.15 if row['Department'] == 'Finance' else row['Salary'], axis=1)

# %%
df_new
# Out:
#    EmployeeID FirstName  LastName        Age   Department    Salary  \
# 0       E0001     David    Miller  26.000000           IT   75734.0
# 1       E0002     Sarah  Williams  49.000000           IT   95339.0
# 2       E0003     Katie   Johnson  53.000000        Sales   80644.0
# 3       E0004     Sarah   Johnson  40.000000        Sales   57543.0
# 4       E0005     Emily     Brown  40.789474      Finance   54606.6
# ..        ...       ...       ...        ...          ...       ...
# 95      E0096     Sarah     Jones  53.000000           IT  111354.0
# 96      E0097     David    Miller  29.000000           IT   41395.0
# 97      E0098     Emily  Williams  40.789474           IT   60334.0
# 98      E0099     Laura    Miller  41.000000    Marketing   95117.0
# 99      E0100   Michael     Brown  33.000000  Engineering   87932.0
#
#         Location JoiningDate        FullName  SalaryAfterTax  \
# 0       New York  2010-12-27    David Miller         60587.2
# ...

# %%
df_new[df_new['Department']=='Finance']
# Out:
#    EmployeeID FirstName  LastName        Age Department     Salary  \
# 4       E0005     Emily     Brown  40.789474    Finance   54606.60
# 6       E0007   Michael  Martinez  34.000000    Finance   72529.35
# 9       E0010     Sarah    Miller  60.000000    Finance  104629.30
# 14      E0015     Emily     Brown  40.789474    Finance  103832.35
# 20      E0021     Chris  Martinez  35.000000    Finance   64993.40
# 41      E0042     Emily    Garcia  48.000000    Finance  134950.20
# 46      E0047   Michael     Jones  31.000000    Finance   50114.70
# 68      E0069     Katie    Garcia  32.000000    Finance  129736.10
# 72      E0073     Katie  Williams  50.000000    Finance   87045.80
# 76      E0077     Emily  Martinez  55.000000    Finance   55343.75
# 78      E0079     Katie     Jones  33.000000    Finance  124085.00
# 80      E0081     Emily   Johnson  40.789474    Finance   82329.65
# 81      E0082     Chris  Martinez  56.000000    Finance   56650.15
# ...

# %%
df
# Out:
#    EmployeeID FirstName  LastName        Age   Department  Salary  \
# 0       E0001     David    Miller  26.000000           IT   75734
# 1       E0002     Sarah  Williams  49.000000           IT   95339
# 2       E0003     Katie   Johnson  53.000000        Sales   80644
# 3       E0004     Sarah   Johnson  40.000000        Sales   57543
# 4       E0005     Emily     Brown  40.789474      Finance   47484
# ..        ...       ...       ...        ...          ...     ...
# 95      E0096     Sarah     Jones  53.000000           IT  111354
# 96      E0097     David    Miller  29.000000           IT   41395
# 97      E0098     Emily  Williams  40.789474           IT   60334
# 98      E0099     Laura    Miller  41.000000    Marketing   95117
# 99      E0100   Michael     Brown  33.000000  Engineering   87932
#
#         Location JoiningDate        FullName  SalaryAfterTax  \
# 0       New York  2010-12-27    David Miller         60587.2
# ...
